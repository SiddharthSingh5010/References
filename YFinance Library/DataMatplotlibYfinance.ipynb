# %%
# Out:
# ^C

# %%
import yfinance as yf
import pandas as pd
import json
# Out:
# WARNING: You are using pip version 21.1.1; however, version 21.1.3 is available.
# You should consider upgrading via the 'c:\python395\python.exe -m pip install --upgrade pip' command.
# ...

# %%
apple = yf.Ticker("AAPL")
amd = yf.Ticker("AMD")

# %%
apple_info=apple.info
apple_info
amd_info=amd.info
amd_info
# Out:
# {'zip': '95054',
#  'sector': 'Technology',
#  'fullTimeEmployees': 12600,
# ...

# %%
apple_info['country']
# Out:
# 'United States'

# %%
amd_info['sector']
# Out:
# 'Technology'

# %%
apple_share_price_data = apple.history(period="max")

# %%
amd_pricedata=amd.history(period='max')

# %%
amd_pricedata['Volume'][0]
# Out:
# 219600

# %%
apple_share_price_data.head()
# Out:
#                 Open      High       Low     Close     Volume  Dividends  \
# Date
# 1980-12-12  0.100751  0.101189  0.100751  0.100751  469033600        0.0
# 1980-12-15  0.095933  0.095933  0.095495  0.095495  175884800        0.0
# 1980-12-16  0.088923  0.088923  0.088485  0.088485  105728000        0.0
# 1980-12-17  0.090676  0.091114  0.090676  0.090676   86441600        0.0
# 1980-12-18  0.093304  0.093742  0.093304  0.093304   73449600        0.0
#
#             Stock Splits
# Date
# 1980-12-12           0.0
# 1980-12-15           0.0
# 1980-12-16           0.0
# 1980-12-17           0.0
# 1980-12-18           0.0

# %%
apple_share_price_data.reset_index(inplace=True)

# %%
# Out:
# pandas.core.frame.DataFrame

# %%
apple_share_price_data.plot(figsize=(20,10),x="Date", y="Volume")
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
apple_share_price_data1=apple_share_price_data.drop(['Stock Splits','Close','Dividends','Volume'],axis=1)

# %%
apple_share_price_data2=apple_share_price_data.copy()

# %%
apple_share_price_data2.plot.line(figsize=(20,10),x='Date',y=['Close','Dividends'],title='Apple Inc.',xlabel='Period (1980-2020)')
# Out:
# <AxesSubplot:title={'center':'Apple Inc.'}, xlabel='Period (1980-2020)'>

# %%
apple_share_price_data2.plot.line(figsize=(20,10),x='Date',y=['Close','Open'],title='Apple Inc.',logy=True,xlabel='Date')
# Out:
# <AxesSubplot:title={'center':'Apple Inc.'}, xlabel='Date'>

# %%
apple_share_price_data1.plot.line(figsize=(20,10),x='Date',y='Open',color= {'Open':'red'})
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
apple_share_price_data1.plot.line(figsize=(20,10),x='Date',color= {'Open':'red','High':'blue','Low':'yellow'})
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
apple_share_price_data1.plot.line(figsize=(20,10),x='Date',color= {'Open':'red','High':'blue','Low':'yellow'},subplots=True)
# Out:
# array([<AxesSubplot:xlabel='Date'>, <AxesSubplot:xlabel='Date'>,
#        <AxesSubplot:xlabel='Date'>], dtype=object)
